# %% [markdown]
# # Challenge 2: Sentiment Analysis
#
# In this challenge we will learn sentiment analysis and practice performing sentiment analysis on Twitter tweets.
#
# ## Introduction
#
# Sentiment analysis is to *systematically identify, extract, quantify, and study affective states and subjective information* based on texts ([reference](https://en.wikipedia.org/wiki/Sentiment_analysis)). In simple words, it's to understand whether a person is happy or unhappy in producing the piece of text. Why we (or rather, companies) care about sentiment in texts? It's because by understanding the sentiments in texts, we will be able to know if our customers are happy or unhappy about our products and services. If they are unhappy, the subsequent action is to figure out what have caused the unhappiness and make improvements.
#
# Basic sentiment analysis only understands the *positive* or *negative* (sometimes *neutral* too) polarities of the sentiment. More advanced sentiment analysis will also consider dimensions such as agreement, subjectivity, confidence, irony, and so on. In this challenge we will conduct the basic positive vs negative sentiment analysis based on real Twitter tweets.
#
# NLTK comes with a [sentiment analysis package](https://www.nltk.org/api/nltk.sentiment.html). This package is great for dummies to perform sentiment analysis because it requires only the textual data to make predictions. For example:
#
# ```python
# >>> from nltk.sentiment.vader import SentimentIntensityAnalyzer
# >>> txt = "Ironhack is a Global Tech School ranked num 2 worldwide. Our mission is to help people transform their careers and join a thriving community of tech professionals that love what they do."
# >>> analyzer = SentimentIntensityAnalyzer()
# >>> analyzer.polarity_scores(txt)
# {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.8442}
# ```
#
# In this challenge, however, you will not use NLTK's sentiment analysis package because in your Machine Learning training in the past 2 weeks you have learned how to make predictions more accurate than that. The [tweets data](https://www.kaggle.com/kazanova/sentiment140) we will be using today are already coded for the positive/negative sentiment. You will be able to use the Naïve Bayes classifier you learned in the lesson to predict the sentiment of tweets based on the labels.

# %%
import re
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer 
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# ## Conducting Sentiment Analysis
#
# ### Loading and Exploring Data
#
# The dataset we'll be using today is located on Kaggle (https://www.kaggle.com/kazanova/sentiment140). Once you have downloaded and imported the dataset, it you will need to define the columns names: df.columns = ['target','id','date','flag','user','text']
#
# *Notes:*
#
# * The dataset is huuuuge (1.6m tweets). When you develop your data analysis codes, you can sample a subset of the data (e.g. 20k records) so that you will save a lot of time when you test your codes.

# %%
full_data = pd.read_csv('..\..\Sentiment140.csv')

# %%
full_data.columns = ['target','id','date','flag','user','text']

# %%
sample = full_data.sample(n = 10000)

# %% [markdown]
# ### Prepare Textual Data for Sentiment Analysis
#
# Now, apply the functions you have written in Challenge 1 to your whole data set. These functions include:
#
# * `clean_up()`
#
# * `tokenize()`
#
# * `stem_and_lemmatize()`
#
# * `remove_stopwords()`
#
# Create a new column called `text_processed` in the dataframe to contain the processed data. At the end, your `text_processed` column should contain lists of word tokens that are cleaned up. Your data should look like below:
#
# ![Processed Data](data-cleaning-results.png)

# %%
def clean_up(s):
    
    return re.sub('[^a-z]', ' ', re.sub('http[s]?://[/\w\.]*', '', 
                                        s.lower()))

# %%
def tokenize(s):
    
    return word_tokenize(s)

# %%
def stem_and_lemmatize(l):
#     nltk.download('wordnet')
    from nltk.stem import WordNetLemmatizer 
    from nltk.corpus import wordnet
    from nltk.stem import PorterStemmer
    ps = PorterStemmer()
    [ps.stem(w) for w in l]
    lemmatizer = WordNetLemmatizer() 
    [lemmatizer.lemmatize(word) for word in l]

    return l

# %%
def remove_stopwords(l):
    from nltk.corpus import stopwords
#     nltk.download('stopwords')
    return list(set(l).difference(stopwords.words()))

# %%
clean_text = sample['text'].apply(clean_up)

# %%
tokens = clean_text.apply(tokenize)

# %%
stem_lem = tokens.apply(stem_and_lemmatize)

# %%
sample['text_processed'] = stem_lem.apply(remove_stopwords)

# %%
sample.head()
# Out:
#          target          id                          date      flag  \
# 797907        0  2328348120  Thu Jun 25 09:28:19 PDT 2009  NO_QUERY
# 120704        0  1833295093  Sun May 17 22:51:05 PDT 2009  NO_QUERY
# 1163843       4  1979708417  Sun May 31 04:11:01 PDT 2009  NO_QUERY
# 1078419       4  1967866165  Fri May 29 20:21:09 PDT 2009  NO_QUERY
# 1503757       4  2072032704  Sun Jun 07 20:17:09 PDT 2009  NO_QUERY
#
#                 user                                               text  \
# 797907      Freisher  @daydreamwriter work!   But yeah, we can do so...
# 120704       RayRayD                   sad i didnt get to see him...
# 1163843  Xn00bXb00bX  Hit the lights is freaking amazing, gonna go l...
# 1078419  marshymelly  @Spannny are you coming over tonight? If so br...
# 1503757       sanlyn                 okay, apartments clean. Goodnight
#
#                                             text_processed
# 797907   [next, something, work, daydreamwriter, maybe,...
# 120704                              [didnt, sad, see, get]
# 1163843  [hit, gon, lights, go, leepies, goodnight, fre...
# 1078419  [coming, like, work, spannny, bit, stuff, math...
# 1503757               [goodnight, okay, clean, apartments]

# %% [markdown]
# ### Creating Bag of Words
#
# The purpose of this step is to create a [bag of words](https://en.wikipedia.org/wiki/Bag-of-words_model) from the processed data. The bag of words contains all the unique words in your whole text body (a.k.a. *corpus*) with the number of occurrence of each word. It will allow you to understand which words are the most important features across the whole corpus.
#
# Also, you can imagine you will have a massive set of words. The less important words (i.e. those of very low number of occurrence) do not contribute much to the sentiment. Therefore, you only need to use the most important words to build your feature set in the next step. In our case, we will use the top 5,000 words with the highest frequency to build the features.
#
# In the cell below, combine all the words in `text_processed` and calculate the frequency distribution of all words. A convenient library to calculate the term frequency distribution is NLTK's `FreqDist` class ([documentation](https://www.nltk.org/api/nltk.html#module-nltk.probability)). Then select the top 5,000 words from the frequency distribution.

# %%
from nltk.probability import FreqDist

def flatten(input_list):
    return [item for sublist in input_list for item in sublist]
text_processed = flatten(sample['text_processed'])

fdist = FreqDist(text_processed).most_common(5000)
fdist
# Out:
# [('good', 563),
#  ('day', 552),
#  ('get', 463),
#  ('like', 453),
#  ('today', 442),
#  ('go', 438),
#  ('got', 426),
#  ('love', 416),
#  ('work', 403),
#  ('going', 392),
#  ('time', 355),
#  ('lol', 354),
#  ('back', 353),
#  ('know', 309),
#  ('really', 307),
#  ('still', 283),
#  ('night', 272),
#  ('new', 269),
#  ('amp', 248),
#  ('see', 244),
#  ('home', 243),
#  ('thanks', 243),
#  ('think', 243),
#  ('morning', 238),
#  ('oh', 234),
#  ('well', 225),
#  ('need', 221),
#  ('great', 214),
#  ('much', 213),
#  ('twitter', 211),
#  ('quot', 210),
#  ('hope', 210),
#  ('tomorrow', 208),
#  ('miss', 205),
#  ('last', 199),
#  ('sorry', 189),
#  ('haha', 185),
#  ('fun', 184),
#  ('sad', 180),
#  ('feel', 179),
#  ('bad', 178),
#  ('sleep', 173),
#  ('make', 166),
#  ('right', 166),
#  ('would', 162),
#  ('wish', 162),
#  ('gon', 160),
#  ('tonight', 157),
#  ('happy', 157),
#  ('getting', 155),
#  ('days', 151),
#  ('way', 147),
#  ('though', 146),
#  ('wait', 144),
#  ('watching', 137),
#  ('people', 135),
#  ('bed', 135),
#  ('week', 134),
#  ('school', 134),
#  ('could', 131),
#  ('nice', 131),
#  ('yeah', 127),
#  ('better', 126),
#  ('dont', 124),
#  ('next', 122),
#  ('hate', 122),
#  ('even', 122),
#  ('lt', 120),
#  ('wan', 118),
#  ('weekend', 117),
#  ('cant', 116),
#  ('little', 115),
#  ('feeling', 112),
#  ('working', 111),
#  ('long', 110),
#  ('soon', 109),
#  ('thank', 108),
#  ('first', 106),
#  ('awesome', 105),
#  ('yes', 105),
#  ('us', 104),
#  ('ok', 103),
#  ('never', 102),
#  ('another', 102),
#  ('already', 101),
#  ('trying', 100),
#  ('hey', 100),
#  ('thing', 97),
#  ('looking', 97),
#  ('guys', 96),
#  ('phone', 95),
#  ('tired', 93),
#  ('please', 92),
#  ('x', 90),
#  ('show', 90),
#  ('done', 90),
#  ('everyone', 89),
#  ('say', 89),
#  ('sick', 89),
#  ('watch', 89),
#  ('always', 88),
#  ('life', 87),
#  ('find', 86),
#  ('sure', 86),
#  ('cool', 85),
#  ('left', 85),
#  ('bored', 85),
#  ('omg', 83),
#  ('friends', 83),
#  ('made', 82),
#  ('help', 80),
#  ('damn', 80),
#  ('movie', 80),
#  ('amazing', 79),
#  ('thought', 79),
#  ('ready', 79),
#  ('friend', 78),
#  ('hours', 78),
#  ('summer', 77),
#  ('yay', 77),
#  ('something', 76),
#  ('sun', 76),
#  ('let', 76),
#  ('ur', 75),
#  ('best', 75),
#  ('keep', 74),
#  ('saw', 74),
#  ('wow', 74),
#  ('went', 74),
#  ('pretty', 74),
#  ('finally', 73),
#  ('makes', 73),
#  ('maybe', 72),
#  ('someone', 72),
#  ('guess', 72),
#  ('follow', 72),
#  ('old', 71),
#  ('beautiful', 71),
#  ('actually', 70),
#  ('yet', 70),
#  ('glad', 70),
#  ('girl', 70),
#  ('nothing', 70),
#  ('song', 69),
#  ('b', 69),
#  ('gone', 69),
#  ('tweet', 68),
#  ('since', 68),
#  ('late', 68),
#  ('missed', 68),
#  ('r', 68),
#  ('live', 68),
#  ('stuff', 67),
#  ('look', 67),
#  ('sucks', 67),
#  ('start', 67),
#  ('things', 67),
#  ('two', 67),
#  ('house', 67),
#  ('god', 66),
#  ('hear', 66),
#  ('looks', 66),
#  ('baby', 65),
#  ('lot', 64),
#  ('big', 64),
#  ('away', 63),
#  ('party', 63),
#  ('hot', 63),
#  ('lost', 62),
#  ('ever', 62),
#  ('early', 61),
#  ('hi', 60),
#  ('said', 60),
#  ('might', 60),
#  ('rain', 60),
#  ('tell', 60),
#  ('bit', 59),
#  ('least', 59),
#  ('yesterday', 59),
#  ('give', 59),
#  ('sounds', 58),
#  ('must', 58),
#  ('ugh', 58),
#  ('later', 58),
#  ('hard', 57),
#  ('excited', 57),
#  ('weather', 57),
#  ('waiting', 57),
#  ('anything', 56),
#  ('friday', 56),
#  ('luck', 56),
#  ('try', 56),
#  ('didnt', 55),
#  ('anyone', 55),
#  ('gt', 55),
#  ('game', 55),
#  ('poor', 54),
#  ('w', 54),
#  ('totally', 54),
#  ('lunch', 53),
#  ('around', 53),
#  ('hurts', 53),
#  ('may', 53),
#  ('coming', 52),
#  ('funny', 52),
#  ('video', 52),
#  ('sunday', 52),
#  ('thats', 52),
#  ('dinner', 51),
#  ('th', 51),
#  ('woke', 51),
#  ('iphone', 51),
#  ('food', 51),
#  ('put', 51),
#  ('car', 51),
#  ('year', 51),
#  ('tho', 51),
#  ('world', 51),
#  ('hour', 51),
#  ('far', 51),
#  ('music', 50),
#  ('finished', 50),
#  ('birthday', 50),
#  ('stupid', 50),
#  ('aww', 50),
#  ('cold', 50),
#  ('free', 50),
#  ('hair', 49),
#  ('real', 49),
#  ('monday', 49),
#  ('without', 49),
#  ('call', 49),
#  ('every', 49),
#  ('shit', 49),
#  ('eat', 49),
#  ('eating', 49),
#  ('forward', 48),
#  ('welcome', 48),
#  ('mean', 47),
#  ('stay', 47),
#  ('family', 47),
#  ('wrong', 47),
#  ('wanted', 47),
#  ('everything', 46),
#  ('p', 46),
#  ('times', 45),
#  ('buy', 45),
#  ('use', 45),
#  ('girls', 45),
#  ('alone', 44),
#  ('believe', 44),
#  ('job', 44),
#  ('followers', 44),
#  ('play', 44),
#  ('leave', 44),
#  ('enjoy', 44),
#  ('many', 44),
#  ('lovely', 44),
#  ('came', 43),
#  ('enough', 43),
#  ('missing', 43),
#  ('g', 43),
#  ('making', 42),
#  ('says', 42),
#  ('weeks', 42),
#  ('almost', 42),
#  ('awww', 42),
#  ('hell', 42),
#  ('read', 42),
#  ('lots', 41),
#  ('true', 41),
#  ('coffee', 41),
#  ('thinking', 41),
#  ('following', 40),
#  ('beach', 40),
#  ('shopping', 40),
#  ('check', 40),
#  ('playing', 40),
#  ('part', 40),
#  ('head', 40),
#  ('run', 39),
#  ('kinda', 39),
#  ('office', 39),
#  ('place', 39),
#  ('problem', 39),
#  ('exam', 39),
#  ('found', 39),
#  ('sweet', 38),
#  ('mom', 38),
#  ('talk', 38),
#  ('room', 38),
#  ('heart', 38),
#  ('hopefully', 38),
#  ('boo', 38),
#  ('stop', 38),
#  ('xx', 38),
#  ('ago', 38),
#  ('okay', 37),
#  ('wont', 37),
#  ('instead', 37),
#  ('whole', 37),
#  ('money', 37),
#  ('tweets', 37),
#  ('listening', 37),
#  ('hit', 36),
#  ('taking', 36),
#  ('news', 36),
#  ('either', 36),
#  ('cuz', 36),
#  ('raining', 36),
#  ('saturday', 36),
#  ('busy', 36),
#  ('btw', 36),
#  ('class', 35),
#  ('probably', 35),
#  ('cause', 35),
#  ('wants', 35),
#  ('hahaha', 35),
#  ('break', 35),
#  ('stuck', 35),
#  ('seems', 35),
#  ('cute', 35),
#  ('hello', 35),
#  ('book', 35),
#  ('outside', 35),
#  ('dad', 34),
#  ('using', 34),
#  ('full', 34),
#  ('pm', 33),
#  ('red', 33),
#  ('hehe', 33),
#  ('heard', 33),
#  ('crazy', 33),
#  ('fine', 33),
#  ('city', 33),
#  ('drive', 32),
#  ('reading', 32),
#  ('tried', 32),
#  ('online', 32),
#  ('win', 32),
#  ('idea', 32),
#  ('awake', 32),
#  ('seen', 32),
#  ('forgot', 32),
#  ('nd', 32),
#  ('breakfast', 32),
#  ('called', 32),
#  ('rest', 32),
#  ('sat', 32),
#  ('boy', 32),
#  ('half', 32),
#  ('goodnight', 31),
#  ('reply', 31),
#  ('sitting', 31),
#  ('seeing', 31),
#  ('post', 31),
#  ('years', 31),
#  ('cry', 31),
#  ('kids', 31),
#  ('mind', 30),
#  ('broke', 30),
#  ('kind', 30),
#  ('turn', 30),
#  ('months', 30),
#  ('feels', 30),
#  ('super', 30),
#  ('running', 30),
#  ('happened', 30),
#  ('else', 30),
#  ('anyway', 30),
#  ('fuck', 30),
#  ('update', 30),
#  ('started', 30),
#  ('seriously', 30),
#  ('concert', 30),
#  ('anymore', 30),
#  ('clean', 29),
#  ('text', 29),
#  ('guy', 29),
#  ('works', 29),
#  ('add', 29),
#  ('site', 29),
#  ('reason', 29),
#  ('mad', 29),
#  ('sooo', 29),
#  ('nap', 29),
#  ('dude', 29),
#  ('hungry', 29),
#  ('leaving', 29),
#  ('told', 28),
#  ('sister', 28),
#  ('asleep', 28),
#  ('starting', 28),
#  ('send', 28),
#  ('saying', 28),
#  ('open', 28),
#  ('ppl', 28),
#  ('xxx', 28),
#  ('remember', 27),
#  ('tickets', 27),
#  ('jealous', 27),
#  ('hurt', 27),
#  ('band', 27),
#  ('boring', 27),
#  ('facebook', 27),
#  ('lucky', 27),
#  ('cut', 27),
#  ('heading', 27),
#  ('afternoon', 27),
#  ('headache', 27),
#  ('picture', 27),
#  ('able', 27),
#  ('youtube', 27),
#  ('ah', 27),
#  ('soo', 27),
#  ('homework', 27),
#  ('tour', 27),
#  ('trip', 27),
#  ('month', 27),
#  ('air', 26),
#  ('english', 26),
#  ('fall', 26),
#  ('talking', 26),
#  ('quite', 26),
#  ('dead', 26),
#  ('internet', 26),
#  ('person', 26),
#  ('longer', 26),
#  ('st', 26),
#  ('tv', 26),
#  ('drinking', 25),
#  ('plan', 25),
#  ('exams', 25),
#  ('favorite', 25),
#  ('goes', 25),
#  ('couple', 25),
#  ('bout', 25),
#  ('change', 25),
#  ('david', 25),
#  ('updates', 25),
#  ('cleaning', 25),
#  ('pics', 25),
#  ('ice', 25),
#  ('fast', 25),
#  ('fucking', 25),
#  ('moment', 25),
#  ('message', 25),
#  ('together', 25),
#  ('bring', 24),
#  ('sleeping', 24),
#  ('supposed', 24),
#  ('account', 24),
#  ('needs', 24),
#  ('aw', 24),
#  ('xd', 24),
#  ('comes', 24),
#  ('hang', 24),
#  ('pay', 24),
#  ('lmao', 24),
#  ('soooo', 24),
#  ('songs', 24),
#  ('interesting', 24),
#  ('write', 24),
#  ('wake', 24),
#  ('blog', 24),
#  ('link', 24),
#  ('nite', 24),
#  ('brother', 24),
#  ('minutes', 24),
#  ('pain', 24),
#  ('ipod', 23),
#  ('crap', 23),
#  ('enjoyed', 23),
#  ('took', 23),
#  ('mtv', 23),
#  ('giving', 23),
#  ('season', 23),
#  ('black', 23),
#  ('fb', 23),
#  ('top', 23),
#  ('ive', 23),
#  ('mileycyrus', 23),
#  ('album', 23),
#  ('course', 23),
#  ('town', 23),
#  ('gets', 23),
#  ('page', 23),
#  ('definitely', 23),
#  ('side', 23),
#  ('drink', 23),
#  ('f', 23),
#  ('congrats', 23),
#  ('horrible', 22),
#  ('computer', 22),
#  ('park', 22),
#  ('bought', 22),
#  ('walk', 22),
#  ('fan', 22),
#  ('high', 22),
#  ('fell', 22),
#  ('died', 22),
#  ('worry', 22),
#  ('fix', 22),
#  ('used', 22),
#  ('studying', 22),
#  ('sunny', 22),
#  ('green', 22),
#  ('goin', 22),
#  ('touch', 22),
#  ('shame', 22),
#  ('luv', 22),
#  ('writing', 22),
#  ('knew', 22),
#  ('ass', 22),
#  ('meeting', 22),
#  ('keeps', 22),
#  ('yummy', 21),
#  ('loves', 21),
#  ('shows', 21),
#  ('hoping', 21),
#  ('tommcfly', 21),
#  ('chance', 21),
#  ('lil', 21),
#  ('hates', 21),
#  ('sound', 21),
#  ('save', 21),
#  ('rock', 21),
#  ('ride', 21),
#  ('beer', 21),
#  ('watched', 21),
#  ('final', 21),
#  ('wonderful', 21),
#  ('yea', 21),
#  ('june', 21),
#  ('seem', 21),
#  ('meet', 21),
#  ('sleepy', 21),
#  ('worst', 21),
#  ('figure', 21),
#  ('wondering', 20),
#  ('star', 20),
#  ('wishing', 20),
#  ('college', 20),
#  ('list', 20),
#  ('loving', 20),
#  ('rather', 20),
#  ('email', 20),
#  ('forget', 20),
#  ('enjoying', 20),
#  ('understand', 20),
#  ('evening', 20),
#  ('fail', 20),
#  ('means', 20),
#  ('eyes', 20),
#  ('sunshine', 20),
#  ('short', 20),
#  ('ask', 20),
#  ('lazy', 20),
#  ('past', 20),
#  ('loved', 20),
#  ('throat', 20),
#  ('worse', 20),
#  ('listen', 20),
#  ('sore', 20),
#  ('movies', 20),
#  ('dear', 19),
#  ('yep', 19),
#  ('flight', 19),
#  ('pool', 19),
#  ('pictures', 19),
#  ('gay', 19),
#  ('bye', 19),
#  ('www', 19),
#  ('spend', 19),
#  ('sometimes', 19),
#  ('dance', 19),
#  ('voice', 19),
#  ('moving', 19),
#  ('second', 19),
#  ('photo', 19),
#  ('church', 19),
#  ('nick', 19),
#  ('via', 19),
#  ('tea', 19),
#  ('visit', 18),
#  ('mood', 18),
#  ('answer', 18),
#  ('laptop', 18),
#  ('worth', 18),
#  ('bitch', 18),
#  ('anyways', 18),
#  ('shall', 18),
#  ('set', 18),
#  ('project', 18),
#  ('sent', 18),
#  ('proud', 18),
#  ('dvd', 18),
#  ('history', 18),
#  ('fair', 18),
#  ('special', 18),
#  ('smile', 18),
#  ('upset', 18),
#  ('graduation', 18),
#  ('whats', 18),
#  ('ddlovato', 18),
#  ('london', 18),
#  ('camera', 18),
#  ('vacation', 18),
#  ('hmm', 18),
#  ('hahah', 18),
#  ('dream', 18),
#  ('jonas', 18),
#  ('scared', 18),
#  ('body', 18),
#  ('power', 18),
#  ('idk', 18),
#  ('weird', 18),
#  ('books', 18),
#  ('wit', 18),
#  ('vote', 18),
#  ('google', 17),
#  ('forever', 17),
#  ('plus', 17),
#  ('hubby', 17),
#  ('goodbye', 17),
#  ('nope', 17),
#  ('disappointed', 17),
#  ('background', 17),
#  ('less', 17),
#  ('card', 17),
#  ('broken', 17),
#  ('move', 17),
#  ('wedding', 17),
#  ('chat', 17),
#  ('road', 17),
#  ('radio', 17),
#  ('magic', 17),
#  ('rainy', 17),
#  ('chocolate', 17),
#  ('awards', 17),
#  ('unfortunately', 17),
#  ('warm', 17),
#  ('finish', 17),
#  ('hugs', 17),
#  ('tuesday', 17),
#  ('huge', 17),
#  ('close', 17),
#  ('agree', 17),
#  ('uk', 17),
#  ('slow', 17),
#  ('water', 17),
#  ('wonder', 17),
#  ('shop', 17),
#  ('sigh', 17),
#  ('officially', 17),
#  ('shoes', 17),
#  ('havent', 17),
#  ('sadly', 17),
#  ('team', 17),
#  ('plane', 17),
#  ('cook', 16),
#  ('wear', 16),
#  ('xoxo', 16),
#  ('laugh', 16),
#  ('ate', 16),
#  ('windows', 16),
#  ('hanging', 16),
#  ('buddy', 16),
#  ('certain', 16),
#  ('packing', 16),
#  ('starts', 16),
#  ('happen', 16),
#  ('slept', 16),
#  ('line', 16),
#  ('decided', 16),
#  ('alright', 16),
#  ('hes', 16),
#  ('single', 16),
#  ('interview', 16),
#  ('unless', 16),
#  ('airport', 16),
#  ('living', 16),
#  ('tummy', 16),
#  ('ones', 16),
#  ('lame', 16),
#  ('white', 16),
#  ('driving', 16),
#  ('dreams', 16),
#  ('babe', 16),
#  ('finals', 16),
#  ('screen', 16),
#  ('arrived', 16),
#  ('absolutely', 16),
#  ('killing', 16),
#  ('catch', 16),
#  ('test', 16),
#  ('shower', 16),
#  ('walking', 16),
#  ('three', 16),
#  ('jonasbrothers', 16),
#  ('hrs', 16),
#  ('followfriday', 16),
#  ('word', 16),
#  ('normal', 15),
#  ('hold', 15),
#  ('business', 15),
#  ('hospital', 15),
#  ('hills', 15),
#  ('club', 15),
#  ('ahh', 15),
#  ('lakers', 15),
#  ('suck', 15),
#  ('father', 15),
#  ('hmmm', 15),
#  ('holiday', 15),
#  ('davidarchie', 15),
#  ('exciting', 15),
#  ('ps', 15),
#  ('meant', 15),
#  ('sold', 15),
#  ('ahhh', 15),
#  ('awwww', 15),
#  ('hand', 15),
#  ('store', 15),
#  ('wasnt', 15),
#  ('moon', 15),
#  ('july', 15),
#  ('photos', 15),
#  ('upload', 15),
#  ('safe', 15),
#  ('john', 15),
#  ('thx', 15),
#  ('cream', 15),
#  ('although', 15),
#  ('perfect', 15),
#  ('gym', 15),
#  ('parents', 15),
#  ('co', 15),
#  ('boys', 15),
#  ('train', 15),
#  ('kidding', 15),
#  ('gorgeous', 15),
#  ('legs', 15),
#  ('myspace', 15),
#  ('sis', 15),
#  ('mum', 15),
#  ('maths', 14),
#  ('garden', 14),
#  ('spring', 14),
#  ('doesnt', 14),
#  ('fat', 14),
#  ('mothers', 14),
#  ('blue', 14),
#  ('episode', 14),
#  ('appreciate', 14),
#  ('paper', 14),
#  ('somewhere', 14),
#  ('mins', 14),
#  ('finale', 14),
#  ('huh', 14),
#  ('story', 14),
#  ('study', 14),
#  ('mother', 14),
#  ('needed', 14),
#  ('exactly', 14),
#  ('dm', 14),
#  ('fever', 14),
#  ('country', 14),
#  ('grrr', 14),
#  ('coz', 14),
#  ('share', 14),
#  ('cake', 14),
#  ('loss', 14),
#  ('hangover', 14),
#  ('thinks', 14),
#  ('dancing', 14),
#  ('eye', 14),
#  ('liked', 14),
#  ('chicken', 14),
#  ('yum', 14),
#  ('date', 14),
#  ('lonely', 14),
#  ('mark', 14),
#  ('app', 14),
#  ('sign', 14),
#  ('join', 14),
#  ('nearly', 14),
#  ('videos', 14),
#  ('daughter', 14),
#  ('happens', 14),
#  ('ff', 14),
#  ('along', 14),
#  ('played', 14),
#  ('apparently', 14),
#  ('def', 14),
#  ('easy', 14),
#  ('case', 14),
#  ('wtf', 14),
#  ('pack', 14),
#  ('front', 14),
#  ('pls', 13),
#  ('feet', 13),
#  ('drunk', 13),
#  ('xo', 13),
#  ('inside', 13),
#  ('australia', 13),
#  ('mr', 13),
#  ('planning', 13),
#  ('especially', 13),
#  ('sims', 13),
#  ('realized', 13),
#  ('young', 13),
#  ('cousin', 13),
#  ('annoying', 13),
#  ('knows', 13),
#  ('except', 13),
#  ('pick', 13),
#  ('worked', 13),
#  ('learn', 13),
#  ('chicago', 13),
#  ('twilight', 13),
#  ('near', 13),
#  ('cd', 13),
#  ('small', 13),
#  ('yup', 13),
#  ('doctor', 13),
#  ('hill', 13),
#  ('hilarious', 13),
#  ('major', 13),
#  ('different', 13),
#  ('matter', 13),
#  ('theres', 13),
#  ('tweeted', 13),
#  ('depressed', 13),
#  ('ladies', 13),
#  ('website', 13),
#  ('beat', 13),
#  ('nose', 13),
#  ('bro', 13),
#  ('woman', 13),
#  ('dunno', 13),
#  ('sexy', 13),
#  ('relaxing', 13),
#  ('crying', 13),
#  ('nobody', 13),
#  ('ahead', 13),
#  ('box', 13),
#  ('usual', 13),
#  ('thursday', 13),
#  ('quick', 13),
#  ('ouch', 13),
#  ('web', 13),
#  ('wishes', 13),
#  ('awful', 13),
#  ('freaking', 12),
#  ('clock', 12),
#  ('otherwise', 12),
#  ('words', 12),
#  ('design', 12),
#  ('mate', 12),
#  ('film', 12),
#  ('laughing', 12),
#  ('fingers', 12),
#  ('fml', 12),
#  ('husband', 12),
#  ('random', 12),
#  ('cell', 12),
#  ('jus', 12),
#  ('point', 12),
#  ('tweeting', 12),
#  ('stand', 12),
#  ('block', 12),
#  ('argh', 12),
#  ('hows', 12),
#  ('lose', 12),
#  ('pissed', 12),
#  ('taken', 12),
#  ('exhausted', 12),
#  ('earlier', 12),
#  ('fans', 12),
#  ('math', 12),
#  ('posted', 12),
#  ('net', 12),
#  ('version', 12),
#  ('miley', 12),
#  ('salad', 12),
#  ('kept', 12),
#  ('likes', 12),
#  ('dr', 12),
#  ('roll', 12),
#  ('chris', 12),
#  ('kno', 12),
#  ('bb', 12),
#  ('dress', 12),
#  ('daddy', 12),
#  ('mobile', 12),
#  ('profile', 12),
#  ('download', 12),
#  ('mac', 12),
#  ('wednesday', 12),
#  ('type', 12),
#  ('pass', 12),
#  ('group', 12),
#  ('bf', 12),
#  ('feelin', 12),
#  ('hands', 12),
#  ('training', 12),
#  ('looked', 12),
#  ('bus', 12),
#  ('cos', 12),
#  ('dark', 12),
#  ('number', 12),
#  ('cheese', 12),
#  ('aint', 12),
#  ('kill', 11),
#  ('heat', 11),
#  ('future', 11),
#  ('fight', 11),
#  ('jay', 11),
#  ('fire', 11),
#  ('burnt', 11),
#  ('darn', 11),
#  ('lately', 11),
#  ('install', 11),
#  ('drop', 11),
#  ('noticed', 11),
#  ('company', 11),
#  ('rob', 11),
#  ('direct', 11),
#  ('trek', 11),
#  ('germany', 11),
#  ('issue', 11),
#  ('often', 11),
#  ('fly', 11),
#  ('dnt', 11),
#  ('question', 11),
#  ('women', 11),
#  ('storm', 11),
#  ('code', 11),
#  ('favourite', 11),
#  ('library', 11),
#  ('everybody', 11),
#  ('doin', 11),
#  ('complete', 11),
#  ('french', 11),
#  ('yr', 11),
#  ('tan', 11),
#  ('ball', 11),
#  ('tom', 11),
#  ('four', 11),
#  ('stomach', 11),
#  ('apple', 11),
#  ('boss', 11),
#  ('wife', 11),
#  ('reach', 11),
#  ('mention', 11),
#  ('ohh', 11),
#  ('honey', 11),
#  ('plans', 11),
#  ('england', 11),
#  ('bloody', 11),
#  ('adam', 11),
#  ('jonathanrknight', 11),
#  ('wall', 11),
#  ('crack', 11),
#  ('studio', 11),
#  ('street', 11),
#  ('nyc', 11),
#  ('joy', 11),
#  ('ran', 11),
#  ('prob', 11),
#  ('bag', 11),
#  ('completely', 11),
#  ('cup', 11),
#  ('spent', 11),
#  ('harry', 11),
#  ('bank', 11),
#  ('fit', 11),
#  ('kate', 10),
#  ('taylor', 10),
#  ('dogs', 10),
#  ('brilliant', 10),
#  ('fav', 10),
#  ('desk', 10),
#  ('considering', 10),
#  ('ordered', 10),
#  ('minute', 10),
#  ('beyond', 10),
#  ('serious', 10),
#  ('spanish', 10),
#  ('properly', 10),
#  ('silly', 10),
#  ('jon', 10),
#  ('twitters', 10),
#  ('gotten', 10),
#  ('gave', 10),
#  ('shut', 10),
#  ('deserve', 10),
#  ('shirt', 10),
#  ('center', 10),
#  ...]

# %% [markdown]
# ### Building Features
#
# Now let's build the features. Using the top 5,000 words, create a 2-dimensional matrix to record whether each of those words is contained in each document (tweet). Then you also have an output column to indicate whether the sentiment in each tweet is positive. For example, assuming your bag of words has 5 items (`['one', 'two', 'three', 'four', 'five']`) out of 4 documents (`['A', 'B', 'C', 'D']`), your feature set is essentially:
#
# | Doc | one | two | three | four | five | is_positive |
# |---|---|---|---|---|---|---|
# | A | True | False | False | True | False | True |
# | B | False | False | False | True | True | False |
# | C | False | True | False | False | False | True |
# | D | True | False | False | False | True | False|
#
# However, because the `nltk.NaiveBayesClassifier.train` class we will use in the next step does not work with Pandas dataframe, the structure of your feature set should be converted to the Python list looking like below:
#
# ```python
# [
# 	({
# 		'one': True,
# 		'two': False,
# 		'three': False,
# 		'four': True,
# 		'five': False
# 	}, True),
# 	({
# 		'one': False,
# 		'two': False,
# 		'three': False,
# 		'four': True,
# 		'five': True
# 	}, False),
# 	({
# 		'one': False,
# 		'two': True,
# 		'three': False,
# 		'four': False,
# 		'five': False
# 	}, True),
# 	({
# 		'one': True,
# 		'two': False,
# 		'three': False,
# 		'four': False,
# 		'five': True
# 	}, False)
# ]
# ```
#
# To help you in this step, watch the [following video](https://www.youtube.com/watch?v=-vVskDsHcVc) to learn how to build the feature set with Python and NLTK. The source code in this video can be found [here](https://pythonprogramming.net/words-as-features-nltk-tutorial/).

# %% [markdown]
# [![Building Features](building-features.jpg)](https://www.youtube.com/watch?v=-vVskDsHcVc)

# %%
# your code here

# %% [markdown]
# ### Building and Traininng Naive Bayes Model
#
# In this step you will split your feature set into a training and a test set. Then you will create a Bayes classifier instance using `nltk.NaiveBayesClassifier.train` ([example](https://www.nltk.org/book/ch06.html)) to train with the training dataset.
#
# After training the model, call `classifier.show_most_informative_features()` to inspect the most important features. The output will look like:
#
# ```
# Most Informative Features
# 	    snow = True            False : True   =     34.3 : 1.0
# 	  easter = True            False : True   =     26.2 : 1.0
# 	 headach = True            False : True   =     20.9 : 1.0
# 	    argh = True            False : True   =     17.6 : 1.0
# 	unfortun = True            False : True   =     16.9 : 1.0
# 	    jona = True             True : False  =     16.2 : 1.0
# 	     ach = True            False : True   =     14.9 : 1.0
# 	     sad = True            False : True   =     13.0 : 1.0
# 	  parent = True            False : True   =     12.9 : 1.0
# 	  spring = True            False : True   =     12.7 : 1.0
# ```
#
# The [following video](https://www.youtube.com/watch?v=rISOsUaTrO4) will help you complete this step. The source code in this video can be found [here](https://pythonprogramming.net/naive-bayes-classifier-nltk-tutorial/).

# %% [markdown]
# [![Building and Training NB](nb-model-building.jpg)](https://www.youtube.com/watch?v=rISOsUaTrO4)

# %%
# your code here

# %% [markdown]
# ### Testing Naive Bayes Model
#
# Now we'll test our classifier with the test dataset. This is done by calling `nltk.classify.accuracy(classifier, test)`.
#
# As mentioned in one of the tutorial videos, a Naive Bayes model is considered OK if your accuracy score is over 0.6. If your accuracy score is over 0.7, you've done a great job!

# %%
# your code here

# %% [markdown]
# ## Bonus Question 1: Improve Model Performance
#
# If you are still not exhausted so far and want to dig deeper, try to improve your classifier performance. There are many aspects you can dig into, for example:
#
# * Improve stemming and lemmatization. Inspect your bag of words and the most important features. Are there any words you should furuther remove from analysis? You can append these words to further remove to the stop words list.
#
# * Remember we only used the top 5,000 features to build model? Try using different numbers of top features. The bottom line is to use as few features as you can without compromising your model performance. The fewer features you select into your model, the faster your model is trained. Then you can use a larger sample size to improve your model accuracy score.

# %%
# your code here

# %% [markdown]
# ## Bonus Question 2: Machine Learning Pipeline
#
# In a new Jupyter Notebook, combine all your codes into a function (or a class). Your new function will execute the complete machine learning pipeline job by receiving the dataset location and output the classifier. This will allow you to use your function to predict the sentiment of any tweet in real time.

# %%
# your code here

# %% [markdown]
# ## Bonus Question 3: Apache Spark
#
# If you have completed the Apache Spark advanced topic lab, what you can do is to migrate your pipeline from local to a Databricks Notebook. Share your notebook with your instructor and classmates to show off your achievements!

# %%
# your code here
